# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
restaurant_europe_data = pd.read_csv('restaurant_europe_data.csv')

# %%
restaurant_europe_data
# Out:
#         Unnamed: 0                          Name       City  \
# 0                0    Martine of Martine's Table  Amsterdam
# 1                1           De Silveren Spiegel  Amsterdam
# 2                2                       La Rive  Amsterdam
# 3                3                      Vinkeles  Amsterdam
# 4                4     Librije's Zusje Amsterdam  Amsterdam
# ...            ...                           ...        ...
# 125522      125522  Konrad Kaffee- & Cocktailbar     Zurich
# 125523      125523     Blueberry American Bakery     Zurich
# 125524      125524            Restaurant Bahnhof     Zurich
# 125525      125525                    Yoyo Pizza     Zurich
# 125526      125526                         dieci     Zurich
#
#                                             Cuisine_style  Ranking   Rating  \
# 0                         ['French', 'Dutch', 'European']      1.0      5.0
# 1       ['Dutch', 'European', 'Vegetarian Friendly', '...      2.0      4.5
# ...

# %%
restaurant_america_data = pd.read_csv('df_api.csv')

# %%
restaurant_america_data
# Out:
#     Unnamed: 0                     Name                 City  Rating  \
# 0            0    Osha Thai Noodle Cafe  America/Los_Angeles     4.0
# 1            1  Mersea Restaurant & Bar  America/Los_Angeles     5.0
# 2            2          Geoff of Ichido  America/Los_Angeles     5.0
# 3            3  Don of The Bimini Twist  America/Los_Angeles     5.0
# 4            4     Mitchell's Ice Cream  America/Los_Angeles     5.0
# 5            5               Acme Bread  America/Los_Angeles     4.5
# 6            6       Reed and Greenough  America/Los_Angeles     4.5
# 7            7         La Farine Bakery  America/Los_Angeles     4.5
# 8            8             Cafe De Casa  America/Los_Angeles     4.5
# 9            9                 Eight Am  America/Los_Angeles     4.5
# 10          10            B. Patisserie  America/Los_Angeles     4.5
# 11          11                  Tacorea  America/Los_Angeles     4.5
# 12          12     The New Spot On Polk  America/Los_Angeles     4.5
#
# ...

# %%
# Una vez que tengo los dos datasets, los concateno para ampliar mis datos
restaurants=pd.concat([restaurant_europe_data,restaurant_america_data], axis=0, ignore_index=True)

# %%
restaurants
# Out:
#         Unnamed: 0                        Name                 City  \
# 0                0  Martine of Martine's Table            Amsterdam
# 1                1         De Silveren Spiegel            Amsterdam
# 2                2                     La Rive            Amsterdam
# 3                3                    Vinkeles            Amsterdam
# 4                4   Librije's Zusje Amsterdam            Amsterdam
# ...            ...                         ...                  ...
# 125535           8                Cafe De Casa  America/Los_Angeles
# 125536           9                    Eight Am  America/Los_Angeles
# 125537          10               B. Patisserie  America/Los_Angeles
# 125538          11                     Tacorea  America/Los_Angeles
# 125539          12        The New Spot On Polk  America/Los_Angeles
#
#                                             Cuisine_style Ranking Rating  \
# 0                         ['French', 'Dutch', 'European']     1.0    5.0
# ...

# %%
restaurant_total_data = restaurants.fillna('-')

# %%
restaurant_total_data
# Out:
#         Unnamed: 0                        Name                 City  \
# 0                0  Martine of Martine's Table            Amsterdam
# 1                1         De Silveren Spiegel            Amsterdam
# 2                2                     La Rive            Amsterdam
# 3                3                    Vinkeles            Amsterdam
# 4                4   Librije's Zusje Amsterdam            Amsterdam
# ...            ...                         ...                  ...
# 125535           8                Cafe De Casa  America/Los_Angeles
# 125536           9                    Eight Am  America/Los_Angeles
# 125537          10               B. Patisserie  America/Los_Angeles
# 125538          11                     Tacorea  America/Los_Angeles
# 125539          12        The New Spot On Polk  America/Los_Angeles
#
#                                             Cuisine_style Ranking Rating  \
# 0                         ['French', 'Dutch', 'European']     1.0    5.0
# ...

# %%
restaurant_total_data.to_csv('restaurant_total_data.csv')
